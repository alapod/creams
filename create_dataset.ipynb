# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from collections import Counter

# %%
import numpy as np

# %%
import re

# %%
df_links = pd.read_csv('makeupalley.csv', names=['link'], header=None)

# %%
df_links.head()
# Out:
#                                                 link
# 0  https://www.makeupalley.com/product/showreview...
# 1  https://www.makeupalley.com/product/showreview...
# 2  https://www.makeupalley.com/product/showreview...
# 3  https://www.makeupalley.com/product/showreview...
# 4  https://www.makeupalley.com/product/showreview...

# %%
df = pd.read_csv('test_csv.txt', sep=u"\uE000", names=['brand', 'name', 'rating', 'ingredients'], engine='python')

# %%
df['link'] = df_links

# %% [markdown]
# ### First try: ~50% ingredient lists not found

# %%
df.head()
# Out:
#             brand                                               name  rating  \
# 0           Belif                           The-True-Cream-Aqua-Bomb     3.8
# 1      Neutrogena               Hydro-Boost-Gel-Cream-Extra-Dry-Skin     3.1
# 2      Neutrogena  Skin-Clearing-Moisturizer-Daily-Face-Cream-wit...     3.3
# 3     Glow-Recipe             Watermelon-Glow-Pink-Juice-Moisturizer     3.8
# 4  Unlisted-Brand                 E45-Dermatological-Treatment-Cream     4.3
#
#                                          ingredients  \
# 0  Aqua, dipropylene glycol, methyl trimethicone,...
# 1  Water, Dimethicone, Glycerin, Cetearyl Olivate...
# 2                                      ['not found']
# 3                                      ['not found']
# 4                                      ['not found']
#
#                                                 link
# 0  https://www.makeupalley.com/product/showreview...
# 1  https://www.makeupalley.com/product/showreview...
# 2  https://www.makeupalley.com/product/showreview...
# 3  https://www.makeupalley.com/product/showreview...
# 4  https://www.makeupalley.com/product/showreview...

# %%
df.shape
# Out:
# (1431, 5)

# %% [markdown]
# ### Second try - 281 new ingredient lists found

# %%
new_found_df = pd.read_csv('missing_results.csv', names=['brand', 'name', 'rating', 'ingredients'], header=None)

# %%
new_found_df.head()
# Out:
#              brand                                       name  rating  \
# 0      Glow-Recipe     Watermelon-Glow-Pink-Juice-Moisturizer     3.8
# 1   Unlisted-Brand         E45-Dermatological-Treatment-Cream     4.3
# 2            Fresh             ROSE-Deep-Hydration-Face-Cream     4.0
# 3    Paulas-Choice  DEFENSE-Essential-Glow-Moisturizer-SPF-30     3.0
# 4  Tarte-Cosmetics                  Drink-H2O-Hydrating-Boost     2.8
#
#                                          ingredients  \
# 0                                      ['not found']
# 1  White soft Paraffin BP 14.5% w/w, Light Liquid...
# 2  AQUA (WATER),GLYCERIN,ETHYLHEXYL ISONONANOATE,...
# 3  Active Ingredients: Titanium Dioxide 5.25; Zin...
# 4                                      ['not found']
#
#                                                 link
# 0                                                NaN
# 1  https://www.makeupalley.com/product/showreview...
# 2  https://www.makeupalley.com/product/showreview...
# 3  https://www.makeupalley.com/product/showreview...
# 4  https://www.makeupalley.com/product/showreview...

# %%
new_found_df.shape
# Out:
# (872, 4)

# %%
new_links = pd.read_csv('missing_links.txt', sep=u"\uE000", engine='python', header=None)

# %%
new_links.drop(0, inplace=True)

# %%
new_found_df['link'] = new_links

# %%
new_found_df.index = new_found_df['link']

# %%
df.index = df['link']

# %%
df
# Out:
#                                                              brand  \
# link
# https://www.makeupalley.com/product/showreview....           Belif
# https://www.makeupalley.com/product/showreview....      Neutrogena
# https://www.makeupalley.com/product/showreview....      Neutrogena
# https://www.makeupalley.com/product/showreview....     Glow-Recipe
# https://www.makeupalley.com/product/showreview....  Unlisted-Brand
# ...                                                            ...
# https://www.makeupalley.com/product/showreview....           FANCL
# https://www.makeupalley.com/product/showreview....        SHISEIDO
# https://www.makeupalley.com/product/showreview....           Bliss
# https://www.makeupalley.com/product/showreview....             DDF
# https://www.makeupalley.com/product/showreview....  Sage-Skin-Care
#
#                                                                                                  name  \
# link
# https://www.makeupalley.com/product/showreview....                           The-True-Cream-Aqua-Bomb
# https://www.makeupalley.com/product/showreview....               Hydro-Boost-Gel-Cream-Extra-Dry-Skin
# https://www.makeupalley.com/product/showreview....  Skin-Clearing-Moisturizer-Daily-Face-Cream-wit...
# https://www.makeupalley.com/product/showreview....             Watermelon-Glow-Pink-Juice-Moisturizer
# https://www.makeupalley.com/product/showreview....                 E45-Dermatological-Treatment-Cream
# ...                                                                                               ...
# https://www.makeupalley.com/product/showreview....      FENATTY-Moisture-Cream-for-Normal-to-Dry-skin
# https://www.makeupalley.com/product/showreview....                              Oil-Free-Moisture-Gel
# https://www.makeupalley.com/product/showreview....                             Quite-Type-Moisturizer
# https://www.makeupalley.com/product/showreview....                      Ultra-Rich-Moisturizing-Cream
# https://www.makeupalley.com/product/showreview....                                 12-Smoothing-Cream
#
#                                                     rating  \
# link
# https://www.makeupalley.com/product/showreview....     3.8
# https://www.makeupalley.com/product/showreview....     3.1
# https://www.makeupalley.com/product/showreview....     3.3
# https://www.makeupalley.com/product/showreview....     3.8
# https://www.makeupalley.com/product/showreview....     4.3
# ...                                                    ...
# https://www.makeupalley.com/product/showreview....     3.3
# https://www.makeupalley.com/product/showreview....     3.5
# https://www.makeupalley.com/product/showreview....     3.3
# https://www.makeupalley.com/product/showreview....     2.4
# https://www.makeupalley.com/product/showreview....     4.1
#
#                                                                                           ingredients  \
# link
# https://www.makeupalley.com/product/showreview....  Aqua, dipropylene glycol, methyl trimethicone,...
# https://www.makeupalley.com/product/showreview....  Water, Dimethicone, Glycerin, Cetearyl Olivate...
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# ...                                                                                               ...
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
#
#                                                                                                  link
# link
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# ...                                                                                               ...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
#
# [1431 rows x 5 columns]

# %%
df['new_ingredients'] = new_found_df['ingredients']

# %%
df['ingredients'] = np.where(df['ingredients']=="['not found']", df['new_ingredients'], df['ingredients'])

# %%
df
# Out:
#                                                              brand  \
# link
# https://www.makeupalley.com/product/showreview....           Belif
# https://www.makeupalley.com/product/showreview....      Neutrogena
# https://www.makeupalley.com/product/showreview....      Neutrogena
# https://www.makeupalley.com/product/showreview....     Glow-Recipe
# https://www.makeupalley.com/product/showreview....  Unlisted-Brand
# ...                                                            ...
# https://www.makeupalley.com/product/showreview....           FANCL
# https://www.makeupalley.com/product/showreview....        SHISEIDO
# https://www.makeupalley.com/product/showreview....           Bliss
# https://www.makeupalley.com/product/showreview....             DDF
# https://www.makeupalley.com/product/showreview....  Sage-Skin-Care
#
#                                                                                                  name  \
# link
# https://www.makeupalley.com/product/showreview....                           The-True-Cream-Aqua-Bomb
# https://www.makeupalley.com/product/showreview....               Hydro-Boost-Gel-Cream-Extra-Dry-Skin
# https://www.makeupalley.com/product/showreview....  Skin-Clearing-Moisturizer-Daily-Face-Cream-wit...
# https://www.makeupalley.com/product/showreview....             Watermelon-Glow-Pink-Juice-Moisturizer
# https://www.makeupalley.com/product/showreview....                 E45-Dermatological-Treatment-Cream
# ...                                                                                               ...
# https://www.makeupalley.com/product/showreview....      FENATTY-Moisture-Cream-for-Normal-to-Dry-skin
# https://www.makeupalley.com/product/showreview....                              Oil-Free-Moisture-Gel
# https://www.makeupalley.com/product/showreview....                             Quite-Type-Moisturizer
# https://www.makeupalley.com/product/showreview....                      Ultra-Rich-Moisturizing-Cream
# https://www.makeupalley.com/product/showreview....                                 12-Smoothing-Cream
#
#                                                     rating  \
# link
# https://www.makeupalley.com/product/showreview....     3.8
# https://www.makeupalley.com/product/showreview....     3.1
# https://www.makeupalley.com/product/showreview....     3.3
# https://www.makeupalley.com/product/showreview....     3.8
# https://www.makeupalley.com/product/showreview....     4.3
# ...                                                    ...
# https://www.makeupalley.com/product/showreview....     3.3
# https://www.makeupalley.com/product/showreview....     3.5
# https://www.makeupalley.com/product/showreview....     3.3
# https://www.makeupalley.com/product/showreview....     2.4
# https://www.makeupalley.com/product/showreview....     4.1
#
#                                                                                           ingredients  \
# link
# https://www.makeupalley.com/product/showreview....  Aqua, dipropylene glycol, methyl trimethicone,...
# https://www.makeupalley.com/product/showreview....  Water, Dimethicone, Glycerin, Cetearyl Olivate...
# https://www.makeupalley.com/product/showreview....                                                NaN
# https://www.makeupalley.com/product/showreview....  White soft Paraffin BP 14.5% w/w, Light Liquid...
# https://www.makeupalley.com/product/showreview....  AQUA (WATER),GLYCERIN,ETHYLHEXYL ISONONANOATE,...
# ...                                                                                               ...
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                                NaN
#
#                                                                                                  link  \
# link
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# ...                                                                                               ...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
# https://www.makeupalley.com/product/showreview....  https://www.makeupalley.com/product/showreview...
#
#                                                                                       new_ingredients
# link
# https://www.makeupalley.com/product/showreview....                                                NaN
# https://www.makeupalley.com/product/showreview....                                                NaN
# https://www.makeupalley.com/product/showreview....                                                NaN
# https://www.makeupalley.com/product/showreview....  White soft Paraffin BP 14.5% w/w, Light Liquid...
# https://www.makeupalley.com/product/showreview....  AQUA (WATER),GLYCERIN,ETHYLHEXYL ISONONANOATE,...
# ...                                                                                               ...
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                      ['not found']
# https://www.makeupalley.com/product/showreview....                                                NaN
#
# [1431 rows x 6 columns]

# %%
df_2
# Out:
#                    brand                                               name  \
# 0                  Belif                           The-True-Cream-Aqua-Bomb
# 1             Neutrogena               Hydro-Boost-Gel-Cream-Extra-Dry-Skin
# 3            Glow-Recipe             Watermelon-Glow-Pink-Juice-Moisturizer
# 4         Unlisted-Brand                 E45-Dermatological-Treatment-Cream
# 5                Eucerin                        Q10-Anti-Wrinkle-Face-Creme
# ..                   ...                                                ...
# 835  Dr.-Brandt-Skincare                                       Poreless-Gel
# 836             Osmotics                              Triceram-DISCONTINUED
# 837             CLINIQUE  Exceptionally-Soothing-Cream-for-Upset-Skin-DI...
# 838        The-Body-Shop             Grape-Seed-Daily-Hydrating-Moisturizer
# 839                  DDF                     EPF-C3-Moisturizer-with-SPF-15
#
#      rating                                        ingredients  \
# 0       3.8  Aqua, dipropylene glycol, methyl trimethicone,...
# 1       3.1  Water, Dimethicone, Glycerin, Cetearyl Olivate...
# 3       3.8  White soft Paraffin BP 14.5% w/w, Light Liquid...
# 4       4.3  AQUA (WATER),GLYCERIN,ETHYLHEXYL ISONONANOATE,...
# 5       4.2  Nov 2019: Water, glycerin, ethylhexyl cocoate,...
# ..      ...                                                ...
# 835     3.5  WATER (AQUA), HAMAMELIS VIRGINIANA(WITCH HAZEL...
# 836     4.2  Water, C12-15 Alkyl Octanoate, C12-15 Alcohol ...
# 837     3.9  Active ingredient: Hydrocortisone Acetate 0.5 ...
# 838     3.6  Purified Water, Glycerin, Tricaprylin, Isocety...
# 839     3.9  Water","Polyglyceryl-3 Methylglucose Distearat...
#
#                                                   link
# 0    https://www.makeupalley.com/product/showreview...
# 1    https://www.makeupalley.com/product/showreview...
# 3    https://www.makeupalley.com/product/showreview...
# 4    https://www.makeupalley.com/product/showreview...
# 5    https://www.makeupalley.com/product/showreview...
# ..                                                 ...
# 835  https://www.makeupalley.com/product/showreview...
# 836  https://www.makeupalley.com/product/showreview...
# 837  https://www.makeupalley.com/product/showreview...
# 838  https://www.makeupalley.com/product/showreview...
# 839  https://www.makeupalley.com/product/showreview...
#
# [839 rows x 5 columns]

# %%
df.index = range(df.shape[0])

# %%
df.drop(df[df['ingredients'] == "['not found']"].index, inplace=True)

# %%
df.drop('new_ingredients', axis=1, inplace=True)

# %%
df_2 = df.dropna(subset=['ingredients'])

# %%
df.nunique()
# Out:
# brand          225
# name           836
# rating          31
# ingredients    837
# link           841
# dtype: int64

# %%
df_2.to_csv('cream_data_v1.csv', index=None)

# %% [markdown]
# ### Most popular brands

# %%
most_common_brands = df['brand'].value_counts().head(50)

# %% [markdown]
# ### Explore ingredient lists

# %%
df = pd.read_csv('cream_data_v1.csv') #dropped NaN

# %%
df['rating'].mean()
# Out:
# 3.7238379022646027

# %%
ing_df = df[['ingredients', 'rating']]

# %%
ing_df
# Out:
#                                            ingredients  rating
# 0    Aqua, dipropylene glycol, methyl trimethicone,...     3.8
# 1    Water, Dimethicone, Glycerin, Cetearyl Olivate...     3.1
# 2    White soft Paraffin BP 14.5% w/w, Light Liquid...     3.8
# 3    AQUA (WATER),GLYCERIN,ETHYLHEXYL ISONONANOATE,...     4.3
# 4    Nov 2019: Water, glycerin, ethylhexyl cocoate,...     4.2
# ..                                                 ...     ...
# 834  WATER (AQUA), HAMAMELIS VIRGINIANA(WITCH HAZEL...     3.5
# 835  Water, C12-15 Alkyl Octanoate, C12-15 Alcohol ...     4.2
# 836  Active ingredient: Hydrocortisone Acetate 0.5 ...     3.9
# 837  Purified Water, Glycerin, Tricaprylin, Isocety...     3.6
# 838  Water","Polyglyceryl-3 Methylglucose Distearat...     3.9
#
# [839 rows x 2 columns]

# %%
all_ingredients = '\n'.join(ing_df['ingredients'].values)

# %%
seps = [',', 'â€¢', '\n', ' . ', '[]', ';', '•', '"', '<br>', 'ingredients', '........................\t', '*', '\t', ' / ', 'ï½¥', ' ? ']

# %%
def split(txt, seps, pattern):
    default_sep = seps[0]
    for sep in seps[1:]:
        txt = txt.replace(sep, default_sep)
    pattern = re.compile(pattern)
    txt = re.sub(pattern, '', txt)
    return [i.strip().lower() for i in txt.split(default_sep)]

# %%
a = split(all_ingredients, seps, '\(.*?\)')

# %%
len(a)
# Out:
# 28372

# %%
b = Counter(a).most_common()[::-1]

# %% [markdown]
# # unique values to clean

# %%
b[3590]
# Out:
# ('alcohol denat. sd alcohol 40-b', 1)

# %%
unique_values = [x[0] for x in b[:3591]]

# %%
unique_values
# Out:
# ['tocopheryl linoleate.',
#  'tridecyl behenate',
#  'water/aqua/eau. cyclopentasiloxane',
#  'eu: sea whip extract',
#  'active ingredient: hydrocortisone acetate 0.5',
#  'propylene glycol.',
#  'acrylated/c10-30 alkyl acrylate cross polymer',
#  'primrose extract',
#  'sunflower extract',
#  'cornflower extract',
#  'c12-15 alcohol benzoate',
#  'c12-15 alkyl octanoate',
#  'silanediol salicylate',
#  'ammonium acryloyldimethyltaurate vp copolymer',
#  'ppg-26 buteth-26',
#  'propylene glycol/pvm/ma copolymer',
#  'glyceryl polymenthacrylate',
#  'hamamelis virginiana extract',
#  'trifluoromethyl c14 alkyl dimethicone',
#  'betula alba  extract',
#  'water purified',
#  'lavendula angustiflia',
#  'aloe barbadensis leaf',
#  'sodium chloride vitamin c complex',
#  'peg/ppg-18/18',
#  'retinyl palmitate polypeptide',
#  'glytamic acid',
#  'srginine',
#  'camellia oleifera seed extract',
#  'dimethicone 6/8/09',
#  'this product has been discontinued.',
#  'cl 17200',
#  'alpha methylionone',
#  'lauryl aminopropylglycine',
#  'lauryl diethylenediaminoglycine',
#  'dimethicone/vinyldimethicone crosspolymer',
#  'saccharum officinarum extract',
#  'citrus medica limonium fruit extract',
#  'citrus aurantium dulcis fruit extract',
#  'acer saccharum extract',
#  'inactives',
#  'oxybenzone 3%.',
#  'actives',
#  'ingredients from bottle',
#  'lysine hydrochloride',
#  'histidine hydrochloride',
#  'thereonine',
#  'methoxypropanediol',
#  'pentaerythirityl tetrasostearate',
#  'dimetgicone',
#  'chlorophensin',
#  'allanine',
#  'cl 42090/blue1',
#  'penaerythyrityl tetraethylhexanoate',
#  'peg-8/smdi copolymer',
#  'zanthoxylum alatum extract',
#  'watercress extract',
#  'maritime pine extract',
#  'kawa extract',
#  'guava extract',
#  'gnaphalium leontopodium extract',
#  'dulcamara extract',
#  'dl-c12-15 alkyl fumarate',
#  'clover extract',
#  'capryl isostearate',
#  'avobenzone  inactive ingredients: water',
#  'active ingredients: octylmethoxycinnamate',
#  "tocopherol phoebe's review: n/a",
#  'dichlorobenzyl alcohol',
#  'active ingredients: n/a ingredients: water',
#  'cinnamyl alcohol.',
#  'borneol',
#  'tilia vulgaris  extract',
#  'peg-35 castor oil',
#  'peg-6 oleate',
#  'beeswax/cera alba',
#  'menthyl salicylate',
#  'hydrogenated coconut oil',
#  'linalool 6/1/09',
#  'fragrance.  ppd 5.9',
#  '1.2 hexanediol',
#  'feverfew  extract',
#  '6 - napthalate',
#  'soybean  seed extract',
#  'oxybenzone . inactive ingredients: water',
#  'ceramide 6-11',
#  'natural antioxidants and plant sterols. aqua/water',
#  'vitamins',
#  'omega 3 fatty acids',
#  'lipids',
#  'with natural linseed oil & bio-calming complex: active ceramides',
#  'geranoil',
#  'na edta',
#  'dha',
#  'pg',
#  'rosemary leaf ext',
#  'tocopherol ci77891/titanium dioxide',
#  'olive fruit ext',
#  'olea europeae leaf ext',
#  'dioctanoate/neopentyl glycol diethylhexanoate',
#  'neopentyl glycol',
#  'amb5123.',
#  'ylparaben',
#  'pro',
#  'glyceryl stearate  peg-100 stearate',
#  'active ingredients: 15% glycolic compound . inactive ingredients: purified water',
#  'iodopropynl butylcarbamate',
#  'glycyrrhiza inflata root extract',
#  'acrylates/octylacrylamide copolymer',
#  'euphorbia cerifera wax',
#  'copernicia cerifera wax',
#  'polyglyceryl 3 diisostearate',
#  'heather extract',
#  'saxifrage sarmentosa extract',
#  'isocetyl alcohol',
#  'caprylic/capric/stearic trighlyceride',
#  'tricaprylyl citrate',
#  'active ingredient: ubiquinone other ingredients water',
#  'melissa offcinalis leaf extract',
#  'prunus amygdalus dulcis  fruit extract',
#  'pumice',
#  'sodium carbomen',
#  'lauryldimonium hydroxypropyl hydrolyzed soy protein',
#  'neopentyl glyocol diheptanoate',
#  'arginine ferulate',
#  'grapeseed extract',
#  'cinnamomum camphora',
#  'and citrus aurantium dulcis',
#  'litsea cubeba fruit',
#  'menthe arvensis  leaf',
#  'essential oils: citrus tangerine',
#  'avobenzone 3.00%  inactive',
#  ': octinoxate 7.50%',
#  'allyl methacrylates crosspolymer',
#  'butyl avocadate',
#  'trisodium salt.',
#  'ethylenediamine triacetic acid',
#  'potassium isostearate',
#  'olibanum resinoid',
#  'cedarwood oil',
#  'fairtrade organic cocoa butter',
#  'fresh pineapple',
#  'fresh green grapes',
#  'organic almond oil',
#  'green tea infusion',
#  'sodium bicarbonate',
#  'helianthus annuus seed extract',
#  'titanium dioxide 0.96%  inactive ingredients: water purified',
#  'ascorbic acid. 1/22/11',
#  'silica dimethicone silylate',
#  'sunscreen  inactive ingredients: water',
#  'sunscreen  octocrylene 1.25%..................',
#  'sunscreen  octisalate 4%...',
#  'sunscreen  ensulizole 1%....',
#  'purpose:  avobenzone 2%',
#  'active ingredients:',
#  'nitrogen',
#  'c10-30 alkyl acrylate crosspolymer benzyl salicylate geraniol limonene linalool',
#  'zingiber officinale  root extract sodium hyaluronate acrylates',
#  'avena sativa  kernel protein',
#  'tetrasodium edta royal jelly extract',
#  'xanthan gum parfum',
#  'caprylyl glycol cassia angustifolia seed polysaccharide',
#  'carbomer cyathea cumingi leaf extract',
#  'dimethicone palmatic acid',
#  'potassium cetyl phosphate dipalmitoyl hydroxyproline',
#  'sesamum glycol  seed oil',
#  'butylene glycol cetearyl alcohol',
#  'dicaprate',
#  'oxybenzone 2.5% and titanium dioxide 1.1%.',
#  'zinc oxide 3.5%',
#  'are octinoxate 7.5%',
#  'the active',
#  'b30386/2',
#  'glycine soja soybean protein',
#  'acetyl tetrapeptide-9',
#  'ensulizole 1.7%',
#  'tropolone.',
#  'polyglyceryl-2 isostearate',
#  'glycerol',
#  'hexylene glycol 6/1/09',
#  'sodium c8-16 isoalkylsuccinyl lactoglobulin sulfonate',
#  'oxybenzone 3%. ingredients- water',
#  'octisalate 3%',
#  'active ingredients: octinoxate 6%',
#  'bixa orellana seed oil',
#  'paulinia cupana seed extract',
#  'elaeis oleifera oil',
#  'theobroma cacao extract',
#  'polyglyceryl 3 stearate',
#  'acryltes /c10-30 alkyl acrylate crosspolymer',
#  'arachidyl gluocoside',
#  'benhenyl alcohol',
#  '6 napthalate',
#  'oxybenzone 2%. inactive ingredients water',
#  'octocrylene 1.5%',
#  'active ingredients avobenzone 2%',
#  'aroma',
#  'organic echinacea  & comfrey  extracts',
#  'resveratrol grapeseed  extract',
#  'standardized green tea  extract',
#  'organic evening primrose  oil',
#  'organic calendula  extract',
#  'food grade xanthan gum',
#  'pure rose wax',
#  'rosehip seed  oil',
#  'organic chamomile  extract',
#  '100% natural non-gmo vitamin e  oil',
#  'dermal respiratory factor',
#  'time-release vitamin c glucoside',
#  'food grade non-gmo lecithin',
#  'organic borage seed  & hazelnut  oils',
#  'food-grade gum arabic',
#  'rice bran  & grapeseed  oils',
#  'sunflower',
#  'lavender oil denatured  extract',
#  'organic jojoba  oil',
#  'organic roses  infused in filtered water',
#  'fd&c blue 1',
#  'ci 61570',
#  'ulva lactuca  extract',
#  'seaweed extract',
#  'marine algae',
#  'carbopol',
#  'watercress  extract',
#  'sea buckthorn berry extract',
#  'sea silk',
#  'organically produced ingredient.  nut/seed based ingredient. natural constituent of essential oils listed. made with 48% organic',
#  'aloe barbadensis  leaf juice powder',
#  'butyrospermum parkii  nut butter',
#  'symphytum officinale  extract',
#  'sodium scymnol sulfate',
#  'modified heteropolysaccharides',
#  'whey  protein',
#  'green olive  extract',
#  'sodium c8-16 isoalkylsuccinyl lactoglobullin sulfonate',
#  'wheat  sphingolipids',
#  'phytomarine extract',
#  'citonellol',
#  'angelica root oil',
#  'hydrolysed quinoa',
#  'chenopodium quinoa extract',
#  'sodium edta',
#  'peg- 10 dimethicone',
#  'sucrose cottonseedate',
#  'tylene glycol',
#  'and vitamin e',
#  'ylang ylang extra and lavender',
#  'organic aroma-therapeutic essential oils of rose geranium',
#  'organic botanical infusion',
#  'cl 14700 .',
#  'cl 194140',
#  'isobutyprabaen',
#  'ehtylparaben',
#  'tetrasodium',
#  'hydrastis canadensis  and cinnamomum zeylanicum bark  1 certified organic by sgs organic 2 certified organic by oregon tilth certified organic',
#  'citrus grandis  seed',
#  'active ingredients: 15% titanium dioxide 10% zinc oxide inactive ingredients: organic aloe barbadensis leaf extract 1',
#  'solanum lycopersicum  fruit.leaf.stem extract',
#  'polyglycerol-10-pentastearate',
#  'peg-114 methyletherpolyepsilon caprolactane',
#  'nicotinamine adenine dinucleotide',
#  'musa sapientum  fruit extract',
#  'morus niagra root extract',
#  'khaya senegalensis bark extract',
#  'glycine soja  sterol',
#  'carboxyvinylpolymer',
#  'actinidia chinesis  fruit extract',
#  'acryclic acid.alkyl methacrylate copolymer',
#  '5-trimethoxycinnamic acid thymol ester',
#  '3',
#  '2-pyrrolidone-5-carboxylic acid',
#  'butylene glycol dicaprylate.dicaprate',
#  'fd&c yellow no. 5 .',
#  'fd&c blue no. 1',
#  'moroccan chamomile oil',
#  'hydrogen peroxide',
#  'triclosan',
#  'zinc oxide . other ingredients: water',
#  'sweet orange essential oil',
#  'pink grapefruit essential oil',
#  'tocotrienol',
#  'japanese green tree extract',
#  'artichoke & alfalfa extracts',
#  'polysorate 20',
#  'botanical infusion of clary sage & chamomile',
#  'isopropyl alcohol',
#  'wild thyme extract',
#  'ci 60730/ext violet 2',
#  'ammonium polyacryldimethyltauramide/ammonium polyacryloyldimethyltaurate',
#  'chrondrus crispus  extract',
#  'acmella oleracea  extract',
#  'denat.',
#  'salvia officinalis',
#  'olea eourpaea',
#  'theobroma cacao',
#  'ylang ylang essential oil',
#  'vanilla extract',
#  'vegetable emulsifying wax',
#  'aftican wild honey',
#  'kpangnan  butter',
#  'virgin coconut  oil',
#  'handcrafted shea  butter',
#  'aloe vera infused with organic rooibos',
#  'glucose oxidase & lactoperoxidase',
#  'vegetable oil & beta carotene',
#  'calendula officinalis',
#  'marshmallow extract',
#  'rosehips fruit oil',
#  'mango seed butter',
#  'filtered water',
#  'potassium sorbate sodium benzoate',
#  'stearyl alcohol thiotic acid',
#  'sodium hylauronate',
#  'carbomer potassium hydroxide',
#  'bisabolol calcium ascorbate',
#  'aloe barbadensis lead juice',
#  'caprylic/capric trigylceride dimethicone',
#  'castor seed oil',
#  'malva sylvestris  extract',
#  'tillia platyphyllos extract',
#  'prunus domestica seed extract',
#  'butyrospermum parkii  oil',
#  'solanum tuberosum extract',
#  'propane',
#  'plant pseudocollagen',
#  'chitosan lactate',
#  'hydrolyzed glycosaminoglycans',
#  '/vinyl  crosspolymer',
#  'ci 77499',
#  'ci 77492',
#  'scutellaria baicalensis',
#  'rosa roxburghii',
#  'hypericum perforatum',
#  'sodium acetylhyaluronate',
#  'soy sterol',
#  'peg-20 hydrogenated castor oil',
#  'methyl gluceth 10',
#  'tetrasodium edta ethylhexylglycerin',
#  'citrus aurantium dulcis  fruit water',
#  'aroma .',
#  'food grade xanthan  & arabic  gums',
#  'organic non-gmo lecithin',
#  'standardized white willow bark extract',
#  'natural retinol liposome',
#  'organic comfrey extract',
#  'organic hazlenut oil',
#  'organic lavender extract',
#  'standardized chamomile extract',
#  'organic borage seed oil',
#  'organic calendula extract',
#  'organic rice germ  & grapeseed  oils',
#  'organic jojoba  & sunflower  oils',
#  'organic rose infusion',
#  'active ingredients: octisalate',
#  'grape  seed extract',
#  'poly hydroxystearic acid',
#  'biguanide',
#  'polyaminopropyl',
#  'coconut alocohol',
#  'ascorbyl alcohol',
#  'aluminium stearate',
#  'sesquistearate',
#  'methyl glucose',
#  'alkyl benzoate',
#  'c12-15',
#  'ester',
#  'c12-20 acid peg-8',
#  'seareth-21',
#  'oxybenzone  inactive: water',
#  'active: avobenzone',
#  'dimethicon 6/8/09',
#  'superoxide dismutase. 7/22/09',
#  'retinyl',
#  'proplyparaben',
#  'ppg-2 myreth propionate',
#  'emulsifying wax glycerin',
#  'sodium chondritin sulfate',
#  'phytosphingnsine',
#  'sodium hyaluraonate',
#  'c30-45 olefin',
#  'stearoxytrimethysilane',
#  'pentaerythrityl tetraisotearate',
#  'jojoba wax peg-120 esters',
#  'fish collagen',
#  'kokum seed butter',
#  'yucca schidigera extract',
#  'rice bran extract',
#  'aloe leaf extract',
#  'propylparaben.h',
#  'phenoxyethanol methyparaben',
#  'iodopropynyl butylcabamate',
#  'c10-11 isoparaffin',
#  'paraffinum loquidum',
#  'sodium cabomer',
#  'glycyrrhiza inflata',
#  'epilobium angustifolium  flower/leaf/stem extract',
#  'cucumis sativus  seed oil',
#  'rosa rubiginosa  seed oil',
#  'flavor',
#  'butylated hydroxyanisole. may contain: ci 77019',
#  'magnesium aluminum silica',
#  'hydroxyethyl acrylates/sodium acryloyldimethyl taurate copolymer',
#  'titanium dioxide 4.5%. inactive ingredients: water',
#  'active ingredients: octocrylene 4%',
#  'methylcellulose.',
#  'aniba rosaeodora  oil',
#  'melaleuca altemifolia  leaf oil',
#  'disodium ed',
#  'silver 6/8/09',
#  'malpighia emarginata  seed extract',
#  'malpighia emarginata  fruit extract',
#  'peg-20 soy sterol',
#  'isopentyldiol',
#  'a proprietary antioxidant forumulation of ddf®. 1/22/11',
#  'xanthophyll. contains redox ii™',
#  'anthocyanins',
#  'acetyl cysteine',
#  'genistein',
#  'sunscreen  inactive ingredients:  water',
#  'sunscreen octocrylene 4% ............',
#  'sunscreen octisalate 2% ...............',
#  'sunscreen octinoxate 7.5%...........',
#  'purpose avobenzone 0.5% ........',
#  'active ingredients',
#  'cl 42090',
#  'gynostemma pentaphyllum extract',
#  'fomes officinalis  extract',
#  'sodium linoleate',
#  'glyceril stearate citrate',
#  'caffeine. morinda citrifolia fruit extract',
#  'palmytoyl oligopeptide',
#  'hydrogenated cetyl olive esters',
#  'soy sterol.',
#  'potassium isosterae',
#  'potassium sterate',
#  'glyceryl sterate se',
#  'butyl methoxydibenzoylmethane 2% w/w.',
#  'octyl methoxycinnamate 5% w/w',
#  'zinc glycyrrhetinate',
#  'oryza sativa  powder',
#  'red rice vinegar',
#  'ci 77891 .',
#  'c18-36 acid glycol ester',
#  'water)',
#  'acrylates/c10-30 alkyl acrylates crosspolymer',
#  '7.5% octinoxate. inactive ingredients: water',
#  'active ingredients: 3.0% avobenzone',
#  'myristoyl /palmitoyl oxostearamide/arachamide mea',
#  'water/eau  sd alcohol 40-b  ethylhexyl palmitate  silica  glycerin  boron nitride  polymethyl methacrylate  cyclopentasiloxane  dimethicone  pyrus malus  fruit extract  hamamelis virginiana  extract  cucurbita pepo  seed extract  vanilla planifolia fruit extract  rubus idaeus  fruit extract  helianthus annuus  seed extract  saccharum officinarum  extract  rubus fruticosus  fruit extract  vitis vinifera  fruit extract  polyacrylamide  c13-14 isoparaffin  laureth-7  caprylic/capric triglyceride  acrylates copolymer  sodium c8-16 isoalkylsuccinyl lactoglobulin sulfonate',
#  'blue 4',
#  'o cymen 5 ol',
#  'peg 50 hydrogenated castor oil isostearate',
#  'akebia trifoliata stem extract',
#  'cnidium officinale root water',
#  'cassia alata  leaf extract',
#  'fagus sylvatica  bud extract',
#  'laminaria ochroleuca  extract',
#  'glycine soja  lipid',
#  'cetearl alcohol',
#  'natural origin',
#  'ingredients issued from organic agriculture.',
#  'gossypium herbaceum  extract',
#  'spermum parkii',
#  'butyro',
#  'la prairieâ€™s exclusive cellular complex us patent 5',
#  'thalassiosira pseodonana extract',
#  'aster maritima extract',
#  'inula crithmoide extract',
#  'crambe maritima extract',
#  'limonium gerberi extract',
#  'acetyl hexapeptide-20',
#  'saccharomyces/carrageenan extract/sarcodiotheca gaudichaudii extract',
#  'c12-15 alkylbenzoate',
#  '- octisalate 5inactive ingredients water',
#  'octinoxate 7.5',
#  'active ingredients: avobenzone 3',
#  'oatmeal extract',
#  'ceramide-6',
#  'ceramide-3',
#  'ceramide-1',
#  'capryylic/capric triglyceride',
#  'aloe vera and zinc oxide.',
#  'grape seed polyphenols',
#  ':     homosalate - 8.0%     octinoxate - 7.5%      octisalate - 5.0%      oxybenzone - 5.0%     avobenzone - 3.0%         water/eau      butylene glycol      glycerin      peg-8      dimethicone      nylon-12      citrus medica limonum  fruit extract      pyrus malus  fruit extract      fumaria officinalis flower/leaf/stem extract      epilobium angustifolium flower/leaf/stem extract      vanilla planifolia fruit extract      theobroma cacao  extract      vaccinium angustifolium  fruit extract      rubus idaeus  fruit extract      rubus fruticosus  fruit extract      vitis vinifera  fruit extract      tromethamine      silica      trimethylsiloxysilicate      glyceryl stearate      hydrogenated lecithin      carbomer      polyglyceryl-3 diisostearate      hydroxyethyl acrylate/sodium acryloyldimethyl taurate copolymer      acrylates/c10-30 alkyl acrylate crosspolymer      squalane      dimethicone/vinyl dimethicone crosspolymer      caprylic/capric triglyceride      fumaric acid      citric acid      disodium edta      benzyl alcohol      cetyl alcohol      polysorbate 60      methylparaben      propylparaben',
#  'methyl/ethyl/butyl/propyl/isobutyl/paraben',
#  'active ingredients: titanium dioxide 12%  inactive ingredients: aqua/water',
#  'ci 15510 .',
#  'daucus carota sativa seed oil',
#  'daucus carota extract',
#  'peg 12 dimethicone',
#  'sucrose tristearate',
#  'dromiceius',
#  'cetyl dimethicone coployol',
#  'diimethicone',
#  'aubrey¹s preservative .',
#  'carrot oil',
#  'coltsfoot extract',
#  'witch hazel  horsetail extract',
#  'water/eau dimethicone butylene glycol glycerin di-c12-15 alkyl fumarate pyridoxine hcl zinc pca camellia sinensis leaf extract dilauryl thiodipropionate sodium hyaluronate caprylic/capric triglyceride dimethicone crosspolymer silica sorbitan isostearate isohexadecane hydroxyethyl acrylate/sodium acryloyldimethyl taurate copolymer acrylates/c10-30 alkyl acrylate crosspolymer polysorbate 60 dna carbomer sodium hydroxide disodium edta phenoxyethanol methylparaben propylparaben caprylyl glycol hexylene glycol parfum/fragrance',
#  'organic',
#  'nettle leaf',
#  'witch hazel water',
#  'coltsfoot leaf extract',
#  'bitter almond oil',
#  'rosa mosqueta seed oil',
#  'acrylates/c10-30 alkylacrylate crosspolymer',
#  'capryyl glycol',
#  'peg/ppg/polybutylene glycol-8/5/5 glycerin',
#  'ingrentient list for aqualia thermal serum puissant:aqua',
#  'boswellia carterii oil',
#  'orzanol',
#  'capric/caprylic trigylceride',
#  'soybean peroxidase',
#  'and avobenzone 2% . other ingredients: water',
#  'oxybenzone 2%',
#  'shea butter  fruit',
#  'jojoba  seed oil',
#  'avocado  oil',
#  'panthanol',
#  'peroxidized corn oil',
#  'zinc oxide 5.0% inactive ingredients: water',
#  'ceteareth-6',
#  'coriandrum sativum',
#  'pyrus malus',
#  'tocopherol  source: plant',
#  'capsicum frutescens resin',
#  'sodium carboxymethyl dextran',
#  'alanyl glutamine',
#  'chamomilla recutita  extract†',
#  'althaea officinalis root extract†',
#  'simmondsia chinensis  leaf extract†',
#  'acrylates copolymer.',
#  'tristearin',
#  'prunus armeniaca/ kernel oil/ apricot kernel oil',
#  'zea mays starch',
#  'other: water purified',
#  'foeniculum vulgare  oil.',
#  'acrylic/acrylate copolymer',
#  'peg-80 hydrogenated castor oil',
#  'sasa kurilensis water',
#  'peg-75',
#  'cysteine',
#  'tyrosine',
#  'leucine',
#  'citrus medica limonum  fruit extr',
#  'acrylates/c10-30 alkyl acrylate crosspol',
#  '2010]',
#  'f.i.l. b11535/3 [september 6',
#  '694327 22',
#  'methylpropional',
#  'butylphenyl',
#  'pyrus malus  fruit water',
#  'triethanolmine',
#  'active ingredients: ensulizole 1.5% octinoxate 7.5% other ingredients: water',
#  'methylparaben. 8/15/09',
#  'egf',
#  'oxybenzone  water',
#  'potassium aspartate',
#  'artemisia abrotanum extract',
#  'acrylates/c10 30 alkyl acrylate crosspolymer',
#  'chlorphenisen',
#  'sodium cocoyl amino acids',
#  'glyceril stearete',
#  'cera micro-cristallina',
#  'canola',
#  'cetyl hydroxyethylcellurose',
#  'lsododecane',
#  'cyclomethicone  polysilicone-11',
#  'ingredients: purified water',
#  'potassium nitrate',
#  'acrylates/c10-30 alkyl acrylata crosspolymer',
#  'hextlene glycol',
#  'polianthes tuberosa  extract',
#  'pueraria lobata root extract. [6/17/15]',
#  'malpighia glabra  fruit extract',
#  'sodium hyaluronate and fragrance .5/23/09',
#  'citrus grandis  fruit and camellia sinensis leaf',
#  'spirulina maxima',
#  'anacyclus pyrethrum root',
#  'extracts of cucumis sativus  seed',
#  'hibiscus esculentus seed extract',
#  'hibiscus esculentus',
#  'ammonium polyacryldimethyltauramide /ammonium polyacryloyldimethyl taurate',
#  'benzyl alchohol',
#  'thiodipropionic',
#  'acrylatesc/10-30 alkyl acrylate crosspolymer',
#  'timethylsiloxysilicate',
#  'argania spinosa leaf extract',
#  'vitisvinifera  seed extract',
#  'hordeum vulgare  extract/extrait d’orge',
#  'octisalate 5.00%.  water/aqua/eau',
#  'avobenzone 3.00 %',
#  'hydroxyisohexyl 3-cylclohexene',
#  'vitreoscilla germent extract',
#  'glyceryl sterate',
#  'alcohol denature',
#  'buyrospermum parkii butter',
#  'ingredients 2013: aqua',
#  'candelilla wax and calendula extract   1 certified organic by oregon tilth certified organic 2 certified organic by organic certifiers 3 certified organic by maryland department of agriculture 4 certified organic by qai',
#  'organic thyme4 and organic lavender4',
#  'organic oregano4',
#  'organic rosemary4',
#  'extract of organic goldenseal3',
#  'organic pomegranate seed extract2',
#  'aloe juice',
#  'tomato lycopene',
#  'carrot seed oil',
#  'alpha-bisabolol',
#  'ester-c sorbitol and glycerin and calcium ascorbate',
#  'ester-c calcium ascorbate',
#  'solanum lycopersicum  fruit lipids',
#  'brassica oleracea italica sprout extract',
#  'malus domestica fruit cell culture',
#  'carbomer methylparaben',
#  'peg-33 castor oil',
#  'peg-32 stearate',
#  'laurdimonium hydroxypropyl hydrolyzed soy protein',
#  'echinacea pallida  extract',
#  'microcrystalline wax\\cera microcristallina\\cire microcristalline',
#  'polybutene',
#  'continuous rescue antioxidant moisturizer very dry to dry formula',
#  'ingredients: 10% mint and orange blossom aromatic waters. 10% original orange water the liquid constituent of the orange  2% extract of codium  2% hazelnut plant oil',
#  'hydroxypalmitoyl sphinganne',
#  'sodium dicocoylethylenediamine peg-15 sulfate',
#  'glyceril linolenate',
#  'alpha-isomethylionone',
#  'fragrance  triethanolamine',
#  'corn  oil',
#  'litsea cubeba  & cinnamomum camphora  pure essential oils.',
#  'dimethylaminoethanol',
#  'linum usitatissimum  seed & borago officinali  seed',
#  'benzyl salycilate',
#  'dihydroxyacetic acid',
#  'benzoicacid',
#  'polyacrilamide',
#  'citrus paradisi ext',
#  'hydrogenated cocoglycerides',
#  'citrus unhius ext',
#  'rubus idaeus ext',
#  'rosmarinus officinalis ext',
#  'helianthus annuus seed ext',
#  'helychrysum italicum ext',
#  'carum petroselinum ext',
#  'anthemis nobilis flower ext',
#  'echium lycopsis oil',
#  'camelina sative seed oil',
#  'glyceryl strearate',
#  'gentiana lutea root ext',
#  'stearyl alcoohl',
#  'bg',
#  'cetearyl alcool',
#  'and other essential oils.',
#  'orgainic lavandula angustifolia  oil',
#  'oenothera bienis  oil',
#  'organic borago officinalis  and simmondsia chinensis  oils',
#  'salix alba  and calendula officinalis extracts',
#  'cucumis sativus',
#  'organic prunus amygdalus  oil',
#  'tocopherol and tocopherol acetate',
#  'glycerl monolaurate',
#  'tromethmine stearate',
#  'organic helianthus annuus oil',
#  'chamomilla recutita  and camelia sinensis  extracts',
#  'perfluoropolymethylisopropyl ether',
#  'caprylic/capric/linoleic triglyceride',
#  'arachidyl behenate',
#  'triticum tulgare  germ extract',
#  'polyglyceryl-3 methyl glucose distearate',
#  'propylpareben',
#  'corbomer',
#  'trimethoxycaprylsilane',
#  'nelumbium speciosum flower extract',
#  'herogenated coco-glycerides',
#  'buyle methoxydibenzoylmethane',
#  'tapicoa startch',
#  'stearic acied',
#  'sodium ascorbyl phosphate^^^',
#  'tocopheryl acetate^',
#  '2% ensulizole. also contains: water',
#  '2.25% octocrylene',
#  'active ingredients: 8.0% homosalate',
#  'citrus aurantium essential oils',
#  'pelargonium graveolens',
#  'melissa officinalis',
#  'helichrysum stoechas',
#  'daucus carota sativa  seed',
#  'chamomilla recutita flower',
#  'botanical extracts of calendula officinalis flower',
#  'vinis vitifera seed oil',
#  'vaccinium macrocarpon seed oil',
#  'linum usitatissimum seed oil',
#  'helianthus annuus oil',
#  'acrylates/c10-30 alkyl acrylate crosspolymer bha sodium hyaluronate sodium carboxymethyl betaglucan butylene glycol',
#  'sodium hydroxide tocopherol linoleic acid',
#  'caprylyl glycol castenea sativa  extract',
#  'parfum  palmitic acid',
#  'carbomer vitis vinifera  seed extract',
#  'polymethyl methacrylate tocopheryl acetate dimethicone lonicera caprifolium  flower extract',
#  'potassium cetyl phosphate cetearyl wheat straw glycosides',
#  'panthenol hydrogenated stearyl olive esters',
#  'cetearyl wheat bran glycosides',
#  'glycine soya sterols',
#  'geranio',
#  'sucrose polysoyate',
#  'maltooligosyl glucoside',
#  'sodium carbomer 941',
#  'active ingredients: dimethicone inactive ingredients: purified water',
#  'red no 4.',
#  'maltodextrin.',
#  'c20-22 alcohols',
#  'agave tequilana leaf extract',
#  'yucca schidigera leaf/root/stem extract',
#  'oenothera biennis  flower extract',
#  'hydrolyzed oats',
#  'terminalia ferdinandiana fruit extract',
#  'hamamelis virginiana  bark/twig extract',
#  'opuntia ficus-indica stem extract',
#  'malpighia emarginata  pulp powder',
#  'c20-22 alkyl phosphate',
#  'zinc oxide  3.92%  other/ non-medicinal ingredients/ingrédients nonmédicinaux : water/eau',
#  'octinoxate  6.5%',
#  'active ingredients/ingrédients actifs : oxybenzone  2%',
#  'hydroxyisohexyl 3-cyclohexen',
#  'citral citronellol',
#  'betylpheny methylpropional',
#  'ascorbyl plamitate',
#  'cetyl dimethicone urea',
#  'octinoxate 6% w/w. water/aqua/eau',
#  'polypropylene',
#  'withania somnifera',
#  'chelidonium majus',
#  'octinoxate 6.0% oxybenzone 2.0%   aqua',
#  'hexl cinnamal',
#  'eau de mer',
#  'maris aqua',
#  'persea grattisima  oil',
#  'aqua / eau',
#  'fd&c red #33.',
#  'fd&c blue #1',
#  'punica granatum  peel extract',
#  'silt',
#  'hamamelis virginia flower  water',
#  'benzophenone 3',
#  'capric/caprylic triglycerides',
#  'persea gratissima avocado oil',
#  'daucus carota  seed oil',
#  'daucus carota  juice',
#  'cucumis sativa  water',
#  'rubus chamaemorus seed extract',
#  'lactobionic acid',
#  'octyldecyl neopentanoate',
#  'titanium dioxide 2.10%   inactive: aqua',
#  'active: ethylhexyl methoxycinnamate  7.50%',
#  'organic lavandula angustifolia  oil and other essential oils. 1) certified by quality assurance international 2) certified by pro-cert organic systems 3) certified by international certification services',
#  'calendula officinalis and salix alba  extracts',
#  'organic helianthus annuus  oil',
#  'chamomilla recutita  and camellia sinensis  extracts',
#  'balsam fir needles',
#  'pure water',
#  'royal jelly',
#  'honey cappings',
#  'zinc acetate',
#  'benzyl pca',
#  'dipropylene glycol isoceteth-20 acetate',
#  '10- decanediol',
#  '10-hydroxydecanoic acid',
#  'porphyra umbilicalis extract',
#  'pvm/ma decadiene crosspolymer',
#  'sodium grape seed extract phosphate',
#  'polygonum tinctorium leaf/stem extract',
#  'sanguisorba officinalis  root extract',
#  "hordeum vulgare  extractextrait d'orge",
#  'ormenis multicaulis  oil',
#  'cymbopogon schoenanthus  oil',
#  ':  citrus aurantium amara  flower water',
#  'inactive',
#  'octisalate avobenzone',
#  ': homosalate',
#  'proplyparabane',
#  'methylparabane',
#  'polymethylsilesquioxane',
#  'nop certified organic',
#  'populus tremuloides  bark extract',
#  'tanacetum annuum  flower oil',
#  'prunus persica  extract',
#  'calophyllum inophyllum  oil',
#  'prunus armeniaca  extract',
#  'cetyl esters wax',
#  'retionol',
#  'phenoxyehtanol',
#  'oxybenzone 4inactive',
#  'octocrylene 3',
#  'avobenzone 1.5',
#  'cinnamon extract',
#  'golden seat root extract',
#  'chaparral extract',
#  'meadowsweet extract',
#  'sandalwood extract',
#  'dog rose hips extract',
#  'velocitytm fragrance',
#  'phosphate. tocopheryl acetate',
#  'linoleamidopropyl pg-dimonium chloride',
#  'non-paraben/does not release formaldehyde] 6/28/09',
#  'optiphen [preservative',
#  'galactobarian',
#  'strawberry seed oil',
#  'blueberry seed oil',
#  'hazelnut oil',
#  'chardonnay oil',
#  'marula oil',
#  'shea oil',
#  'yogurt',
#  'oat milk',
#  'polawax nf [emulsifier]  or  sugarmulse/stearic acid [waxless version]',
#  'german chamomile hydrosol',
#  'aloe juice [not gel]',
#  'phytosteryl rice branate',
#  "st. john's wort",
#  'organic blue camomile oil',
#  "aubrey's preservative:",
#  'organic green tea powder',
#  'aloe vera oil',
#  'd-alpha tocopherol',
#  'white camellia oil',
#  'and arnica',
#  'cucumber',
#  'pellitory',
#  'ivy',
#  'blue mallow',
#  'german camomile',
#  'linden',
#  'camomile',
#  'extracts of: calendula',
#  'milk thistle extract',
#  'organic rosa mosqueta® rose hip seed oil',
#  'padimate o',
#  'benzyll alcohol',
#  'rosadamascena flower oil',
#  'manihot uttissima starch',
#  'tetrasodium pyrophosphate',
#  'spiraea ulmaria',
#  'acrylates/vinyl isodecanoate crosspolymer',
#  'lauryl methacrylate/glycol dimethacrylate crosspolymer',
#  'laureth 4',
#  'hydroxyphenyl propamidobenzoic acid',
#  'ceteth 20',
#  'peg 75 stearate',
#  'polyamide 5',
#  'oxybenzone    inactive ingredients: water',
#  'solanium lycopersicum extract/tomato extract',
#  'ceteth-10',
#  'ascorbyl glycoside',
#  'actinidia chinensis water/kiwi fruit water',
#  'vinyl dimethicone crosspolymer',
#  'natural ingredient',
#  'certified organic ingredient',
#  'natural fragrance',
#  'organic simmondsia chinensis  oil',
#  'organic punica granatum  oil',
#  'organic chamomilla recutina  extract',
#  'organic aloe barbadnesis  leaf extract',
#  'organic argan spinosa  kernel oil',
#  'decy oeate',
#  'hexadecene copolymer',
#  'eugenia carophyllus  flower oil.',
#  'citrus retuclata  leaf oil',
#  'elettairia cardamommum seed oil',
#  'pheonoxyethanol',
#  'chlorphensesin',
#  'tocoperyl acetate',
#  'cyclopenstisolxane',
#  'corn startch modified',
#  'oxybenzone 3% ingredients: water',
#  'active ingredients octinoxate 7.5%',
#  'chrysanthemum parthenium  flower/leaf/stem juice',
#  'artemisia abrotanum flower/leaf/stem extract',
#  'c13-14 isoparafn',
#  'chamaemelum nobile  extract',
#  'undaria pinnatifida extract',
#  'butyrospermum parkll  butter',
#  'cl42090/blue 1',
#  'cl 19140/yellows',
#  'butyrospermum paprkii/shea butter',
#  'praline',
#  'chamomilla recutita flower extract',
#  'nylon 12',
#  'dunaliella)',
#  'dunaliella',
#  'spirulina',
#  'red pepper extract',
#  'watermelon extract',
#  'propolis cera extract',
#  'tomatoes extract',
#  'red tea extract',
#  'chamomilla recutita extract',
#  'active ingredient: salicylic acid . inactive ingredients: water',
#  'ceratonia siliqua  fruit extracts',
#  'camellia kissi seed oil silica',
#  'tetrasodium etidronate',
#  'ammonium polyacrylodimethyl taurate',
#  'octinoxate 7.5%. inactive',
#  ': ensulizole 1.8%',
#  'penathenol',
#  'active ingredients: 7.5% octyl methoxycinnamate',
#  'magnesium ascorbyl phosphate\\',
#  'organic cinnamon3 and organic lavender3',
#  'organic goldenseal4',
#  'organic oregano3',
#  'organic thyme3',
#  'extracts of organic rosemary3',
#  'organic cocoa butter1',
#  'organic beeswax3',
#  'organic pomegranate oil3',
#  'organic acai berry oil',
#  'organic pomegranate2 and organic acai berry3',
#  'organic blueberry2',
#  'organic blackberry2',
#  'organic chamomile1',
#  'extracts of organic calendula1',
#  'organic white tea1',
#  'beta-carotene .',
#  'dna',
#  'agarum cribosum extract',
#  'averrhoa carambola leaf extract .',
#  'punica granatum seed oil',
#  'linseed oil/palm oil aminopropanediol esters',
#  'isopropyl jojobate',
#  'titanium dioxide 0.6%',
#  'oxybenzone 0.45%',
#  ': ensulizole 7.7%',
#  'water/eau dimethicone glycerin peg-8 butylene glycol rubus idaeus  fruit extract rubus fruticosus  fruit extract vitis vinifera  fruit extract sanguisorba officinalis root extract pyrus malus  fruit extract lotus japonicus symbiosome extract morus bombycis root extract glycyrrhiza glabra  root extract molasses extract/extrait de melasse aloe barbadensis leaf extract scutellaria baicalensis root extract citrus aurantium dulcis  fruit extract citrus medica limonum  fruit extract vanilla planifolia fruit extract arctostaphylos uva ursi leaf extract bis-peg-15 dimethicone/ipdi copolymer hdi/trimethylol hexyllactone crosspolymer silica acrylates/c10-30 alkyl acrylate crosspolymer polymethyl methacrylate glycereth-26 peg-20 methyl glucose sesquistearate hydroxyethyl acrylate/sodium acryloyldimethyl taurate copolymer dimethicone crosspolymer squalane sodium polyacrylate methyl undecylenate ethyl undecylenate dimethiconol sodium hydroxide polysorbate 60 benzophenone-4 phytol caprylic/capric triglyceride sodium hyaluronate andrographolide xymenynic acid phosphoric acid polysorbate 20 aminobutyric acid glucosamine hcl hydrolyzed soy protein sodium metabisulfite sodium sulfite magnesium ascorbyl phosphate disodium edta phenoxyethanol chlorphenesin sodium dehydroacetate mica titanium dioxide blue 1',
#  'sodium chondrootin sulfate',
#  'peg100 stearate',
#  'garcinia indica  seed butter',
#  'cholestrol/potassium sulfate',
#  'saccahromyces ferment lysate filtrate',
#  'oruza sativa  bran extract cucumis melo  fruit extract',
#  'rubus fruticosus  leaf extract',
#  'camellia sinensis leaf powder',
#  'dibutyl adipate',
#  'zinc oxide . inactives: water',
#  'dimethicone peg 10/15 crosspolymer',
#  'soybean proein',
#  'octisalate 5% water',
#  'geogard ultra',
#  'leucidal',
#  'tamanu oil',
#  'sugarmulse',
#  'coconut cream',
#  'coconut endosperm',
#  'coconut milk',
#  'green]',
#  'coconut water [young',
#  'glyceryl polymethylacrylate',
#  'st. paul’s wort extract',
#  'sodium mannose phosphate',
#  'apple fruit extract',
#  'turmeric root extract',
#  'argania spinosa lead extract',
#  'centaury extract',
#  'chestnut seed extract',
#  'coffee seed extract',
#  'coriander seed oil',
#  'ginger root oil',
#  'bergamot fruit oil',
#  'grapefruit peel oil',
#  'bitter orange flower water',
#  'myrtle leaf water',
#  'ci 75130/beta-carotene.',
#  'persa gratissima/avocado oil',
#  'prunus armeniaca/apricot kernel oil',
#  'prunus amygdalus dulcis/sweet almond oil',
#  'olea europaea/olive fruit oil',
#  'sorbitan strerate',
#  'akebia trifoliata',
#  'butyrospermum parkii oil',
#  'seawater',
#  'ingredient',
#  'lonicera caprifoliu  and citrus grandis seed',
#  'origanum vulgare leaf',
#  'vanilla planifolia fruit',
#  'extracts of organic aloe barbadensis leaf 5',
#  'extracts of coffea arabica leaf/seed  and organic coffea arabica leaf/seed 4',
#  'seabuckthorn  oil',
#  'organic rosa canina  seed oil3',
#  'organic rosa centifolia flower water 2',
#  'extracts of organic camellia sinensis leaf 1 and camelia sinensis leaf 1',
#  'sodium pca sorbitol',
#  'pg-dimonium chloride phosphate',
#  'linoleamidopropyl',
#  'lauramide oxide',
#  'butyphenyl methylpropional',
#  'hydroxyethyl behenamidopropyl dimonium chloride',
#  'polyquaternium-67',
#  'kefiran',
#  'acetyl decapeptide-3',
#  'helianthus annuss  seed oil unsaponifiables',
#  'polyglyceryl-3 methyglucose distearate',
#  'c12-15 alkyl ethyhexanoate',
#  ...]

# %%
extracts = [x for x in unique_values if 'extract' in x]

# %%
oils = [x for x in unique_values if 'oil' in x]

# %%
alcohols = [x for x in unique_values if 'alcohol' in x]

# %%
len(extracts)
# Out:
# 772

# %%
len(oils)
# Out:
# 375

# %%
len(alcohols)
# Out:
# 58

# %%
long = [x for x in unique_values if len(x) > 50]

# %%
short_oils = [x for x in oils if len(x) < 80]

# %%
short_oils
# Out:
# ['peg-35 castor oil',
#  'hydrogenated coconut oil',
#  'with natural linseed oil & bio-calming complex: active ceramides',
#  'geranoil',
#  'essential oils: citrus tangerine',
#  'cedarwood oil',
#  'organic almond oil',
#  'sesamum glycol  seed oil',
#  'bixa orellana seed oil',
#  'elaeis oleifera oil',
#  'organic evening primrose  oil',
#  'rosehip seed  oil',
#  '100% natural non-gmo vitamin e  oil',
#  'organic borage seed  & hazelnut  oils',
#  'rice bran  & grapeseed  oils',
#  'lavender oil denatured  extract',
#  'organic jojoba  oil',
#  'angelica root oil',
#  'organic aroma-therapeutic essential oils of rose geranium',
#  'moroccan chamomile oil',
#  'sweet orange essential oil',
#  'pink grapefruit essential oil',
#  'ylang ylang essential oil',
#  'virgin coconut  oil',
#  'vegetable oil & beta carotene',
#  'rosehips fruit oil',
#  'castor seed oil',
#  'butyrospermum parkii  oil',
#  'peg-20 hydrogenated castor oil',
#  'organic hazlenut oil',
#  'organic borage seed oil',
#  'organic rice germ  & grapeseed  oils',
#  'organic jojoba  & sunflower  oils',
#  'cucumis sativus  seed oil',
#  'rosa rubiginosa  seed oil',
#  'aniba rosaeodora  oil',
#  'melaleuca altemifolia  leaf oil',
#  'peg 50 hydrogenated castor oil isostearate',
#  'daucus carota sativa seed oil',
#  'carrot oil',
#  'bitter almond oil',
#  'rosa mosqueta seed oil',
#  'boswellia carterii oil',
#  'jojoba  seed oil',
#  'avocado  oil',
#  'peroxidized corn oil',
#  'prunus armeniaca/ kernel oil/ apricot kernel oil',
#  'foeniculum vulgare  oil.',
#  'peg-80 hydrogenated castor oil',
#  'carrot seed oil',
#  'peg-33 castor oil',
#  'corn  oil',
#  'litsea cubeba  & cinnamomum camphora  pure essential oils.',
#  'echium lycopsis oil',
#  'camelina sative seed oil',
#  'and other essential oils.',
#  'orgainic lavandula angustifolia  oil',
#  'oenothera bienis  oil',
#  'organic borago officinalis  and simmondsia chinensis  oils',
#  'organic prunus amygdalus  oil',
#  'organic helianthus annuus oil',
#  'citrus aurantium essential oils',
#  'vinis vitifera seed oil',
#  'vaccinium macrocarpon seed oil',
#  'linum usitatissimum seed oil',
#  'helianthus annuus oil',
#  'persea grattisima  oil',
#  'persea gratissima avocado oil',
#  'daucus carota  seed oil',
#  'organic helianthus annuus  oil',
#  'ormenis multicaulis  oil',
#  'cymbopogon schoenanthus  oil',
#  'tanacetum annuum  flower oil',
#  'calophyllum inophyllum  oil',
#  'strawberry seed oil',
#  'blueberry seed oil',
#  'hazelnut oil',
#  'chardonnay oil',
#  'marula oil',
#  'shea oil',
#  'organic blue camomile oil',
#  'aloe vera oil',
#  'white camellia oil',
#  'organic rosa mosqueta® rose hip seed oil',
#  'rosadamascena flower oil',
#  'organic simmondsia chinensis  oil',
#  'organic punica granatum  oil',
#  'organic argan spinosa  kernel oil',
#  'eugenia carophyllus  flower oil.',
#  'citrus retuclata  leaf oil',
#  'elettairia cardamommum seed oil',
#  'camellia kissi seed oil silica',
#  'organic pomegranate oil3',
#  'organic acai berry oil',
#  'punica granatum seed oil',
#  'linseed oil/palm oil aminopropanediol esters',
#  'tamanu oil',
#  'coriander seed oil',
#  'ginger root oil',
#  'bergamot fruit oil',
#  'grapefruit peel oil',
#  'persa gratissima/avocado oil',
#  'prunus armeniaca/apricot kernel oil',
#  'prunus amygdalus dulcis/sweet almond oil',
#  'olea europaea/olive fruit oil',
#  'butyrospermum parkii oil',
#  'seabuckthorn  oil',
#  'organic rosa canina  seed oil3',
#  'helianthus annuss  seed oil unsaponifiables',
#  'citrus aurantium amara  peel oil',
#  'cottonseed oil',
#  'orange essential oil',
#  'sea buckthorn fruit oil',
#  'meadowfoam seed oil',
#  'olive oil unsaponifiables',
#  'sea buckthorn seed oil',
#  'mentha piperita oil',
#  'amyris balsamifera bark oil',
#  'angelica archangelica root oil',
#  'limnanthes alba seed oil/meadowfoam seed oil',
#  'components of natural essential oils',
#  'fragrance oils .',
#  'shea butter oil',
#  'macademia ternifolia seed oil',
#  'citrus reticulata  essential oil',
#  'citrus aurantium  essential oil',
#  'litsea cubeba   essential oil',
#  'citrus bergamia  essential oil',
#  'citrus arauntifolia  essential oil',
#  'citrus limonium  essential oil',
#  'citrus deliciosa  essential oil',
#  'citrus cinensis  essential oil',
#  'azadirachta indica  oil',
#  'rosa mosqueta  seed oil',
#  'vitis vinifera  oil',
#  'callitris intratropica wood oil',
#  'hibiscus seed oil',
#  'cold pressed organic starflower oil',
#  'organic coconut oil',
#  'litsea cubeba  & cananga odorata  pure essential oils',
#  'fragrance oil blend.',
#  'rubus chamemorus seed oil',
#  'salvia sclarea essential oil',
#  'lavandula angustifolia essential oil',
#  'triticum vulgare  oil',
#  'helianthus annuus  seed oilm',
#  'carnation oil',
#  'sunflower oil/palm oil aminopropanediol esters',
#  'helianthus annuus  seed oil unsaponifiables',
#  'vanilla planifolia  oil',
#  'myristica fragrans  kernel oil',
#  'cinnamomum zeylanicum  leaf oil',
#  'rice bran  oil',
#  'litsea cubeba  and cinnamomum camphora  essential oils',
#  'organic plant oils of butyrospermum parkii',
#  'fusanus spicatus wood  oil',
#  'echium plantagineum  seed oil',
#  'persia gratissima  oil unsaponifiables',
#  'tea tree leaf oil',
#  'taraktogenos kurzii seed oil',
#  'calophyllum tacamahca seed oil',
#  'dromiceius oil',
#  'rosa rubiginosa seed oil',
#  'echium plantagineum seed oil',
#  'hydrogenated olive oil  olive  oil  olive oil unsaponifiables',
#  'simmondsia chinesis  seed oil',
#  'persia gratissima  oil and persia gratissima  oil unsaponifiables',
#  'citrus limon  peel oilâ€',
#  'citrus aurantium dulcis  peel oilâ€',
#  'citrus aurantium bergamia  fruit oilâ€',
#  'cananga odorata  oil',
#  'peg 60 hydrogenated castor oil',
#  'essential oils of lavender',
#  'vegetable oils of safflower',
#  'helianthus annus  oil',
#  'lavandula  angustifolia oil',
#  'oxycoccus palustris seed oil',
#  'prunus armeniaca  kernal oil',
#  'cathamus tinctorius  seed oil',
#  'olea europa  fruit oil',
#  'perilla ocymoides seed oil',
#  'cold pressed jojoba oil',
#  'lavendula angustifolia  oil',
#  'litsea cubeba  and cinnamomum camphora  pure essential oils',
#  'organic plant oils of helianthus annuus',
#  'pomegranate fruit oil',
#  'rosehip seed oil',
#  'cranberry seed oil',
#  'lemon oil',
#  'hydrolyzed sunflower and safflower oil',
#  'olea europaea fruit oil/olea europaea  fruit oil',
#  'cocos nucifera oil/cocos nucifera  oil',
#  'simmondsia chinensis seed oil/simmondsia chinensis  seed oil',
#  'moringa oleifera seed oil',
#  'prunus amygdalus dulcis oil/sweet almond oil',
#  'occurs naturally in essential oils',
#  'chamomile blue oil',
#  'olea europaea  oil',
#  'lanolin liquida  oil',
#  'juniperous communis  fruit oil',
#  'leptospermum scoparium  oil',
#  'rosa damascena  oil',
#  'mentha arvensis  leaf oil',
#  'prunus amygdalus amara  kernel oil',
#  'abies sibirica  oil',
#  'barosma betulina leaf oil',
#  'corn oil zea mays',
#  'sunflower seed oil glyceride',
#  'sesame oil unsaponifiables sesamum indicum',
#  'avocado oil persea gratissima',
#  'sweet almond oil prunus amygdalus dulcis',
#  'butyrospermum parkii  canola oil',
#  'potassium sorbate essential oils',
#  '- rosemary extract naturally occurring in essential oils: citronellol',
#  '- jojoba oilcarthamus tinctorius seed oil',
#  '- apricot kernel oilsimmondsia chinensis seed oil',
#  'geranium oil',
#  'camella oil',
#  'organic grapeseed oil',
#  'citrus aurantium  & cinnamomum camphora  pure essential oils',
#  'cinnamomum camphora linalloliferum  leaf oil',
#  'corylus americana  seed oil',
#  'hibiscus sabdariffa seed oil',
#  'ribes nigrum oil',
#  'hydrogenated olive oil unsaponifiables',
#  'hydrogenated prunus armeniaca  kerneil oil',
#  'lavundula hybrida oil',
#  'vegetable oil/hydrogenated vegetable oil/euphorbia cerifera  wax',
#  'essential oil.',
#  'sunflower oil decyl esters',
#  'essential oil. ingredients mle cream: aqua',
#  'macadamia ternifoliaseed oil',
#  'aniba rosaeodora  wood oil',
#  'rice bran oil. pentaerythrityl tetra-di-t-butyl hydroxyhydrocinnamate',
#  'bitter orange flower oil',
#  'origanum majorana leaf oil',
#  'camelina sativa oil/camelina sativa seed oil',
#  'glycine soja oil/glycine soja',
#  'triticum vulgare germ oil/triticum vulgare  germ oil',
#  'linum usitatissimum  oil',
#  'rosa canina  oil',
#  'vetiver  root oil',
#  'citrus auranitium bergamia  fruit oil',
#  'essential oils of: jasmium officinale',
#  'aleurites moluccana seed oil',
#  'euterpe oleracea fruit oil',
#  'hydrogenated evening primrose oil',
#  'blackcurrant seed oil',
#  'essential oils of',
#  'extra virgin olive oil',
#  'hazel seed oil',
#  'aristotelia chilensis  seed oil',
#  'calendula officinalis  flower extract  glycine soja  oil',
#  'plum  oil',
#  'natural and fragrant oils',
#  'citrus aurantium amara  oil',
#  'olea europaea  oil unsaponifiables',
#  'sesamum indicum seed oil/sesamum indicum  seed oil',
#  'persea  gratissima  oil',
#  'simmondsia chinensis   seed oil',
#  'rosehip oil',
#  'paraffinum liquidum/mineral oil/huile minerale',
#  'citrus aurantium dulcis  and citrus tangerina  oils',
#  'borago officinalis  and rosa canina  oils',
#  'umnantes alba  seed oil',
#  'camellia sinensis seed oil',
#  'citrus reticulata  peel oil',
#  'orange roughy oil',
#  'apricot kernel oil peg-6 esters',
#  'hydrogenated castor oil dimer dilionleate',
#  'simmondsia  chinensis  seed oil',
#  'fragrance: natural essential oils',
#  'musk rose  oil',
#  'peach  oil',
#  'pongamia glabra seed oil',
#  'natural component of essential oils.',
#  'components of natural essential oils.',
#  'persea gratissima  fruit oil',
#  'cocos nucifera  fruit oil',
#  'hydrogenated olive oil stearyl esters',
#  'olea europea  fruit oil',
#  'echium lypcosis fruit oil',
#  'myrtus communis oil',
#  'sesame oil',
#  'high-oleic safflower oil',
#  'persea gratissima  oil.',
#  'cananga odorata flower  oil',
#  'safflower glyceride/palm oil aminopropanediol esters',
#  'armeniaca  kernel oil',
#  'organic extra virgin olive oil',
#  'rosa moschata seed oil',
#  'prunus amygdatus dulcis oil',
#  'borgago officinalis seed oil',
#  'argania spinose kernal oil',
#  'component of natural essential oils.',
#  'essential oils of: zea mays',
#  'rubus chamaemorus  seed oil',
#  'oxycoccus palustris  seed oil',
#  'brassica campestris  seed oil',
#  'organic aroma-therapeutic essential oils of rose bulgarian',
#  'organic borage oil',
#  'organic tamanu oil',
#  'kukui nut oil',
#  'organic avocado oil',
#  'aniba rosodora  wood oil',
#  'coriandrum sativum fruit oil',
#  'annuus seed oil',
#  'tocopherol macadamia ternifolia seed oil',
#  'chamomile oil',
#  'oryza sativa bran oil',
#  'cold pressed grapeseed oil',
#  'cold pressed avocado oil',
#  'thermus themophillus ferment. comination to oily: ingredients: water',
#  'vetivert oil',
#  'rosewood oil',
#  'rose hip oil',
#  'moringa oil',
#  'lavandula augustifolia  oil',
#  'tricitum vulgare  germ oil',
#  'fucanus spicatus wood oil',
#  'avocado oil unsaponifiables',
#  'salvia hispanica seed oil',
#  'cannabis sativa seed oil',
#  'macadamia seed oil',
#  'triticum vulgare germ oil',
#  'macadamia ternifolia oil and aleurites moluccana  nut oil',
#  'organic oils of sweet almond',
#  'organic sunflower oil',
#  'citrus tangerina  and cymbopogon martini  oils',
#  'safflower oil',
#  'eucalyptus leaf oil',
#  'hippophae rhamnoides  seed oil',
#  'rosa mosqueta  hip oil',
#  'mineral oil/huile minerale',
#  'orange flower oil',
#  'ingredients: jasmine oil',
#  'lime oil',
#  'tangerine oil',
#  'organic cold-pressed wheatgerm oil',
#  'organic cold-pressed evening primrose oil',
#  'organic cold-pressed avocado oil',
#  'triticum vulgare wheat germ oil',
#  'peg 40 castor oil',
#  'cymbopogon citratus leaf oil',
#  'mineral oil  stearic acid',
#  'ecalyptus leaf oil',
#  'mineral oil\\paraffinum liquidum\\huile minã©rale',
#  'argania spinosa kernal oil',
#  'schinziophyton rautanenii kernel oil',
#  'citrullus lanatus  seed oil',
#  'adansonia digitata seed oil',
#  'component of natural essential oils',
#  'vanilla planifolia fruit oil',
#  'rosmarinus officinalis leaf oil',
#  'citrus aurantifolia peel oil expressed',
#  'citrus aurantium dulcis oil']
